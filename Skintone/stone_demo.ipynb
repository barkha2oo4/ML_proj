# %% [markdown]
# # Install `skin-tone-classifier`

# %%
! pip install skin-tone-classifier --upgrade
# Please don't use `pip install skin-tone-classifier[all] --upgrade` because the GUI mode is not compatible with Google Colab.
# Out:
# Collecting skin-tone-classifier
#   Downloading skin_tone_classifier-1.2.4-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: opencv-python>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from skin-tone-classifier) (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.5 in /usr/local/lib/python3.10/dist-packages (from skin-tone-classifier) (1.26.4)
# Collecting colormath>=3.0.0 (from skin-tone-classifier)
#   Downloading colormath-3.0.0.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from skin-tone-classifier) (4.66.6)
# Collecting colorama>=0.4.6 (from skin-tone-classifier)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from skin-tone-classifier) (24.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from skin-tone-classifier) (2.32.3)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from colormath>=3.0.0->skin-tone-classifier) (3.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->skin-tone-classifier) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->skin-tone-classifier) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->skin-tone-classifier) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->skin-tone-classifier) (2024.8.30)
# Downloading skin_tone_classifier-1.2.4-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.5/116.5 kB 5.2 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Building wheels for collected packages: colormath
#   Building wheel for colormath (setup.py) ... done
#   Created wheel for colormath: filename=colormath-3.0.0-py3-none-any.whl size=39406 sha256=94ea95ead45c66ae586691dad456db81d687798370253b7241bb2ff43e5d17a0
#   Stored in directory: /root/.cache/pip/wheels/ab/b3/4d/c0738759c25a1df01958068f162cf2a9dc3ab1da8b972cfcfc
# Successfully built colormath
# Installing collected packages: colormath, colorama, skin-tone-classifier
# Successfully installed colorama-0.4.6 colormath-3.0.0 skin-tone-classifier-1.2.4

# %% [markdown]
# ## Verify the installation
#
# You can check the installed version by `stone -v`

# %%
! stone -v
# Out:
# stone 1.2.4

# %% [markdown]
# # Used in Python script or Jupyter Notebook

# %% [markdown]
# ### Load necessary libraries

# %%
import stone

from google.colab.patches import cv2_imshow # Comment out this line in a python script. `cv2.imshow()` is disabled in Colab, because it causes Jupyter sessions to crash; see https://github.com/jupyter/notebook/issues/3935.

# %%
image_path = "https://raw.githubusercontent.com/ChenglongMa/SkinToneClassifier/main/docs/demo.png" # Use the demo.png stored in my repo

# %%
result = stone.process(image_path, image_type="color", return_report_image=True)

# %%
report_images = result.pop("report_images")  # obtain and remove the report image from the `result`

face_id = 1
cv2_imshow(report_images[face_id]) # Use `stone.show` instead in Python scripts
# Out:
# <PIL.Image.Image image mode=RGB size=450x300>

# %%
# convert the result to json
from json import dumps # Optional

result_json = dumps(result)
result_json
# Out:
# '{"basename": "demo", "extension": ".png", "image_type": "color", "faces": [{"dominant_colors": [{"color": "#E9BFA3", "percent": "0.66"}, {"color": "#A76A53", "percent": "0.34"}], "skin_tone": "#E5C8A6", "tone_label": "CH", "accuracy": 86.53, "face_id": 1}]}'

# %% [markdown]
# ## Used as a [`command-line interface (CLI)`](https://en.wikipedia.org/wiki/Command-line_interface) tool
#
# *NOTE*: The following is just a **simulation** for use on the CLI.
#
# Please remove the *exclamation point* (!) before the command during normal use, see a
# Please refer to https://github.com/ChenglongMa/SkinToneClassifier#how-to-use for more details.

# %%
! stone -i https://raw.githubusercontent.com/ChenglongMa/SkinToneClassifier/main/docs/demo.png --debug
# Out:
# The program is processing your images...
# Please wait for the program to finish.
# Processing demo: 100% 1/1 [00:00<00:00,  2.40images/s, Image Type=color, #Faces=1, Face ID=1, Skin Tone=#E5C8A6, Label=CH, Accuracy=86.5]

# %% [markdown]
# Also, you can process multiple images:

# %%
! stone -i https://raw.githubusercontent.com/ChenglongMa/SkinToneClassifier/main/docs/demo.png https://raw.githubusercontent.com/ChenglongMa/SkinToneClassifier/main/docs/demo_bw.png --debug
# Out:
# The program is processing your images...
# Please wait for the program to finish.
# Processing demo_bw: 100% 2/2 [00:00<00:00,  3.11images/s, Image Type=bw, #Faces=1, Face ID=1, Skin Tone=#D0D0D0, Label=BD, Accuracy=92.2]

# %% [markdown]
# You can click the <kbd>Files</kbd> button on the left to see the outputs, which include `./debug`, and `./result.csv`.

# %%
# !ls
# Out:
# debug  log  result_bak_2412052353.csv  result.csv  sample_data

# %% [markdown]
# Here we just use some Python commands to show the content of results (report images and csv file).

# %%
from IPython.display import Image
Image('./debug/color/faces_1/demo-1.png')

# %%
Image('./debug/bw/faces_1/demo_bw-1.png')

# %%
import pandas as pd

pd.read_csv("./result.csv")
# Out:
#           file image type  face id dominant 1  percent 1 dominant 2  \
# 0     demo.png      color        1    #E9BFA3       0.66    #A76A53
# 1  demo_bw.png         bw        1    #CECECE       0.64    #878787
#
#    percent 2 skin tone tone label  accuracy(0-100)
# 0       0.34   #E5C8A6         CH            86.53
# 1       0.36   #D0D0D0         BD            92.17

# %% [markdown]
# If you have any question or suggestion, please feel free to open a new [Issue](https://github.com/ChenglongMa/SkinToneClassifier/issues) or [Discussion](https://github.com/ChenglongMa/SkinToneClassifier/discussions).
#
# Thanks!
